# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("Delhi2018-2019.csv")

# %%
df.head()
# Out:
#       AT   PM2.5     RH    WS    CO    NO2  Ozone    SO2         AQI
# 0  13.18  481.62  71.69  0.32  3.38  89.52  27.43  21.63  578.169231
# 1  11.63  359.67  71.90  0.34  3.63  83.81  33.64  23.50  484.361538
# 2  12.41  287.71  67.28  0.32  1.82  86.46  28.90  20.49  429.007692
# 3  11.76  351.62  69.67  0.76  1.15  92.60  35.19  21.87  478.169231
# 4  11.22  306.25  67.88  0.80  2.03  81.87  28.93  21.62  443.269231

# %%
delhi = df.loc[df["City"]=='Delhi']

# %%
delhi.to_csv("Delhi_original.csv")

# %%
df = pd.read_csv("Delhi_original.csv")

# %%
# Out:
#       Unnamed: 0   City        Date   PM2.5    PM10     NO    NO2     NOx  \
# 0          10229  Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59
# 1          10230  Delhi  2015-01-02  186.18  269.55  62.09  32.87   88.14
# 2          10231  Delhi  2015-01-03   87.18  131.90  25.73  30.31   47.95
# 3          10232  Delhi  2015-01-04  151.84  241.84  25.01  36.91   48.62
# 4          10233  Delhi  2015-01-05  146.60  219.13  14.01  34.92   38.25
# ...          ...    ...         ...     ...     ...    ...    ...     ...
# 2004       12233  Delhi  2020-06-27   39.80  155.94  10.88  21.46   22.47
# 2005       12234  Delhi  2020-06-28   59.52  308.65  12.67  21.60   23.86
# 2006       12235  Delhi  2020-06-29   44.86  184.12  10.50  21.57   21.94
# 2007       12236  Delhi  2020-06-30   39.80   91.98   5.99  17.96   15.44
# 2008       12237  Delhi  2020-07-01   54.01  128.66   6.33  21.05   16.81
#
#          NH3     CO    SO2     O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# ...

# %%
df.drop(df.columns[3],axis=1,inplace = True)
# Out:
# c:\users\91701\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df
# Out:
#         AT   PM2.5     RH    WS    CO     NO2  Ozone    SO2         AQI
# 0    13.18  481.62  71.69  0.32  3.38   89.52  27.43  21.63  578.169231
# 1    11.63  359.67  71.90  0.34  3.63   83.81  33.64  23.50  484.361538
# 2    12.41  287.71  67.28  0.32  1.82   86.46  28.90  20.49  429.007692
# 3    11.76  351.62  69.67  0.76  1.15   92.60  35.19  21.87  478.169231
# 4    11.22  306.25  67.88  0.80  2.03   81.87  28.93  21.62  443.269231
# ..     ...     ...    ...   ...   ...     ...    ...    ...         ...
# 725  15.63  292.34  79.79  0.36  2.07  246.23  67.34   9.09  432.569231
# 726  13.98  336.75  88.05  0.40  2.39  331.13  65.85  12.24  466.730769
# 727   8.39  359.65  82.52  0.36  2.87  215.10  65.61  11.83  484.346154
# 728   7.49  369.66  94.21  0.94  2.73   63.66  68.05   8.56  492.046154
# 729   7.68  180.26  82.31  1.65  1.98   23.60  65.86   5.01  346.353846
#
# [730 rows x 9 columns]

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# 2    12.41  287.71  67.28  0.32  1.82   86.46  28.90  20.49  429.007692
# 3    11.76  351.62  69.67  0.76  1.15   92.60  35.19  21.87  478.169231
# 4    11.22  306.25  67.88  0.80  2.03   81.87  28.93  21.62  443.269231
# ..     ...     ...    ...   ...   ...     ...    ...    ...         ...
# 725  15.63  292.34  79.79  0.36  2.07  246.23  67.34   9.09  432.569231
# 726  13.98  336.75  88.05  0.40  2.39  331.13  65.85  12.24  466.730769
# 727   8.39  359.65  82.52  0.36  2.87  215.10  65.61  11.83  484.346154
# 728   7.49  369.66  94.21  0.94  2.73   63.66  68.05   8.56  492.046154
# 729   7.68  180.26  82.31  1.65  1.98   23.60  65.86   5.01  346.353846
#
# [730 rows x 9 columns]

# %%
x=df.iloc[:,:-1] 
y=df.iloc[:,-1]

# %%
from sklearn import model_selection as ms
x_train,x_test,y_train,y_test = ms.train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression
algo1 = LinearRegression()
algo1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(algo1.coef_)
print(algo1.intercept_)
# Out:
# [-1.36969363  1.05535747 -0.51779988 -4.77798078 -2.01516838  0.32785542
#   0.24380666  0.84724574]
# 129.12812419400126

# %%
prediction = algo1.predict(x_test)

# %%
sns.distplot(y_test-prediction)
# Out:
# c:\users\91701\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AQI', ylabel='Density'>

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 34.37509460434515
# MSE: 1565.6638081667486
# RMSE: 39.568469873963394

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(x_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
prediction_1 = model.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction_1))
print('MSE:', metrics.mean_squared_error(y_test, prediction_1))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction_1)))
# Out:
# MAE: 1.8234749041191416
# MSE: 18.29377183547591
# RMSE: 4.277121910289197

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# %%
lasso=Lasso()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

lasso_regressor.fit(x_test,y_test)
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# {'alpha': 5}
# -1512.0078349472165
# c:\users\91701\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99460.19894097508, tolerance: 239.53742397010151
#   model = cd_fast.enet_coordinate_descent(
# c:\users\91701\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104128.13197801636, tolerance: 244.54495064709636
#   model = cd_fast.enet_coordinate_descent(
# c:\users\91701\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104405.9595494741, tolerance: 250.95749491241017
# ...

# %%
prediction_2=lasso_regressor.predict(x_test)

# %%
sns.distplot(y_test-prediction)
# Out:
# c:\users\91701\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AQI', ylabel='Density'>

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction_2))
print('MSE:', metrics.mean_squared_error(y_test, prediction_2))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction_2)))
# Out:
# MAE: 33.07415788194125
# MSE: 1443.0790311179069
# RMSE: 37.98788005559019

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor()
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
prediction_3=regressor.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction_3))
print('MSE:', metrics.mean_squared_error(y_test, prediction_3))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction_3)))
# Out:
# MAE: 1.6880703660360978
# MSE: 24.657333574848987
# RMSE: 4.965615125525637

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
 #Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Method of selecting samples for training each tree
# bootstrap = [True, False]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.3s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.2s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 30}

# %%
rf_random.best_score_
# Out:
# -106.16570346872061

# %%
prediction_4=rf_random.predict(x_test)

# %%
sns.distplot(y_test-prediction_4)
# Out:
# c:\users\91701\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AQI', ylabel='Density'>

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction_4))
print('MSE:', metrics.mean_squared_error(y_test, prediction_4))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction_4)))
# Out:
# MAE: 1.4818866072711396
# MSE: 12.480395563119215
# RMSE: 3.5327603319669474
